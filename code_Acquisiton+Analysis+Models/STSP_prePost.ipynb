# %%
from STSP_prePost_baseCode import *

# %%
p['c_PreIn']=0.0
p['pulseAmp']=0.1; p['firstPulseTime']=50.0; p['nPulses']=10; p['period']=50.0
spikeTrain = p['firstPulseTime'] + p['period']* sc.arange(1,p['nPulses']+1)
p['tMax'] = 600.0; p['stepSize'] = 1/40.0; 
p['sampTimes']= sc.arange(0,p['tMax'],p['stepSize'])
p['nSteps']= sc.int32(p['tMax']/p['stepSize'])

# %% [markdown]
# ## Sampling responses from periodic stimulus trains

# %%
# Facilitation profile
p['c_halfAct_r_muM']=0.3; p['tau_c_Pre']=20.0; p['tau_q']=10.0; p['c_PreIn']=0.0
# Depression profile
p['c_halfAct_r_muM']=0.25; p['tau_c_Pre']=20.0; p['tau_q']=40.0; p['c_PreIn']=0.0
# Biphasic profile
p['c_halfAct_r_muM']=0.3; p['tau_c_Pre']=40.0; p['tau_q']=30.0; p['c_PreIn']=0.0
#
c2,q2,rSS2= solve2DDynamics(p,spikeTrain)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-37a1972a04ad> in <module>()
#       6 p['c_halfAct_r_muM']=0.3; p['tau_c_Pre']=40.0; p['tau_q']=30.0; p['c_PreIn']=0.0
#       7 #
# ----> 8 c2,q2,rSS2= solve2DDynamics(p,spikeTrain)
#
# /Users/curandero/scienceMath/membraneBiophysics/presynapticSTSP/STSP_prePost_baseCode.py in solve2DDynamics(p, spikeTrain, dispFig)
#      69         f1=gr.figure(figsize=(15,7)); rows=3; cols=1; ax=list()
#      70         ax=[f1.add_subplot(rows,cols,n+1) for n in range(rows*cols)]
# ---> 71         ax[0].plot(p['sampTimes'],c2,'orange'+'.',label='$c(t)$')
#      72         ax[0].plot(p['sampTimes'],rSS2,'b.',lw=3,alpha=0.4,label='$r_{\infty}(c)$')
#      73         ax[1].plot(p['sampTimes'],q2,'k.',label='$q(t)$')
#
# /usr/local/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1865                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1866                         RuntimeWarning, stacklevel=2)
# -> 1867             return func(ax, *args, **kwargs)
#    1868
#    1869         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/local/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in plot(self, *args, **kwargs)
#    1526         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1527
# -> 1528         for line in self._get_lines(*args, **kwargs):
#    1529             self.add_line(line)
#    1530             lines.append(line)
#
# /usr/local/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _grab_next_args(self, *args, **kwargs)
#     404                 this += args[0],
#     405                 args = args[1:]
# --> 406             for seg in self._plot_args(this, kwargs):
#     407                 yield seg
#     408
#
# /usr/local/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _plot_args(self, tup, kwargs)
#     353         ret = []
#     354         if len(tup) > 1 and isinstance(tup[-1], six.string_types):
# --> 355             linestyle, marker, color = _process_plot_format(tup[-1])
#     356             tup = tup[:-1]
#     357         elif len(tup) == 3:
#
# /usr/local/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _process_plot_format(fmt)
#     128         else:
#     129             raise ValueError(
# --> 130                 'Unrecognized character %c in format string' % c)
#     131         i += 1
#     132
#
# ValueError: Unrecognized character a in format string
